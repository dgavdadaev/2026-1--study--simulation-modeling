# %%
using DrWatson
@quickactivate "project"
include(srcdir("sir_model.jl"))
using .sir_model

using Random, StatsPlots, BenchmarkTools
# Out:
#   Activating project at `~/2026-1--study--simulation-modeling/labs/lab08/project`

# %% [markdown]
# Параметры модели

# %%
tmax = 40.0
uθ = [990, 10, 0]  # S, I, R
p = [0.05, 10.0, 0.25]  # β, c, γ

Random.seed!(1234)
# Out:
# Random.TaskLocalRNG()

# %% [markdown]
# Запуск модели

# %%
des_model = sir_model.MakeSIRModel(uθ, p)
sir_model.activate(des_model)
sir_model.sir_run(des_model, tmax)
data_des = sir_model.out(des_model)
# Out:
# 1516×4 DataFrame
#   Row │ t          S      I      R
#       │ Float64    Int64  Int64  Int64
# ──────┼────────────────────────────────
#     1 │  0.0         990     10      0
#     2 │  0.110851    989     11      0
#     3 │  0.249585    988     12      0
#     4 │  0.314392    987     13      0
#     5 │  0.418738    987     12      1
#     6 │  0.457041    987     11      2
#     7 │  0.528895    986     12      2
#     8 │  0.619502    985     13      2
#   ⋮   │     ⋮        ⋮      ⋮      ⋮
#  1510 │ 39.1229      228     25    747
#  1511 │ 39.1412      228     24    748
#  1512 │ 39.2187      228     23    749
#  1513 │ 39.4599      228     22    750
#  1514 │ 39.7561      227     23    750
#  1515 │ 39.8017      226     24    750
#  1516 │ 39.9933      226     23    751
#                       1501 rows omitted

# %% [markdown]
# Визуализация

# %%
@df data_des plot(
    :t,
    [:S :I :R],
    labels = ["S" "I" "R"],
    xlab = "Время",
    ylab = "Численность",
    title = "Дискретно-событийная SIR модель"
)
savefig(plotsdir("sir_des.png"))
# Out:
# Could not create decoration from factory! Running with no decorations.
# "/home/dgavdadaev/2026-1--study--simulation-modeling/labs/lab08/project/plots/sir_des.png"

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
